# %%
def menuiniciar1 (): #menu inicial do jogo
    print('\t╔╦═╦══╦══╦═╦═╦╗')
    print('\t║║═╣╔╗║░░║╔╣║║║')
    print('\t║║╔╣╚╝║╔╗╣╚╣╩║║')
    print('\t║╚╝╚══╩╝╚╩═╩╩╝║')
    print('\t╚═════════════╝')

    print('\n\t   ╔╦═╦═╦═╦╦╗')
    print('\t  ╔╝║║║╔╣╩║╔╝')
    print('\t  ╚═╩═╩═╩╩╩╝')

    print('\t   ╔══╦═╦╦╦╗')
    print('\t   ╠╗╚╣╩║║╔╝')
    print('\t   ╚══╩╩╩╩╝')    
    
def jogar1 (): #menu jogar 
    print('\t╔╦═╦══╦══╦═╦══╦╗')
    print('\t║╚╗║╔╗║╔═╣║║░░║║')
    print('\t║╔╣║╚╝║╚╝║╩║╔╗╣║')
    print('\t║╚═╩══╩══╩╩╩╝╚╝║')
    print('\t╚══════════════╝')

    print('\n\t   ╔═╦═╦═╦╦╗')
    print('\t   ║╔╣╩║╠╣║╚╗')
    print('\t   ╚╝╚╩╩═╩╩═╝')

    print('\t  ╔══╦═╦═╦╦═╗')
    print('\t  ║║║║╦╣╠║║║║')
    print('\t  ╚╩╩╩═╩═╩╩═╝')

    print('\t  ╔═╦╦═╦╦═╦╦╗')
    print('\t  ║╠║║╔╣║╠╣║╚╗')
    print('\t  ╚═╩╩╝╚╩═╩╩═╝')

    print('\t  ╔══╦═╦═╦╦╗╔╗')
    print('\t  ║║║║╦╣║║║╚╝║')
    print('\t  ╚╩╩╩═╩╩═╩══╝')
    
def painel_facil (): #menu jogar dificuldade fácil
    print('\t╔╦═╦═╦═╦╦╦═╗')
    print('\t║║═╣║║╔╣║║ ║')
    print('\t║║╔╣╩║╚╣║╚╗║')
    print('\t║╚╝╚╩╩═╩╩═╝║')
    print('\t╚══════════╝')
    
    print('\n        ╔╦═╦╦╦═╦╦═╦╦╗')
    print('        ║║║║║║╠╣║╩║╔╝')
    print('        ╚╩╩═╩╩═╩╩╩╩╝')
    
    print('       ╔╦╦═╦╗╔══╦═╦╦╗')
    print('       ║║║║║╚╬╗╔╣╩║╔╝')
    print('       ╚═╩═╩═╝╚╝╚╩╩╝')
    
def painel_medio (): #menu jogar dificuldade média
    print('\t╔╦══╦═╦═╦╦╦══╦╗')
    print('\t║║║║║═╣║╚╣║╔╗║║')
    print('\t║║║║║═╣║╔╣║╚╝║║')
    print('\t║╚╩╩╩═╩═╝╚╩══╝║')
    print('\t╚═════════════╝')
  
    print('\n\t ╔╦═╦╦╦═╦╦═╦╦╗')
    print('\t ║║║║║║╠╣║╩║╔╝')
    print('\t ╚╩╩═╩╩═╩╩╩╩╝')

    print('\t╔╦╦═╦╗╔══╦═╦╦╗')
    print('\t║║║║║╚╬╗╔╣╩║╔╝')
    print('\t╚═╩═╩═╝╚╝╚╩╩╝')    

def painel_dificil (): #menu jogar dificuldade difícil
    print('\t╔╦═╦╦╦═╦╦═╦╦╦═╗')
    print('\t║║║╚╣║═╣║╔╣║║ ║')
    print('\t║║║╔╣║╔╣║╚╣║╚╗║')
    print('\t║╚═╝╚╩╝╚╩═╩╩═╝║')
    print('\t╚═════════════╝')
    
    print('\n\t ╔╦═╦╦╦═╦╦═╦╦╗')
    print('\t ║║║║║║╠╣║╩║╔╝')
    print('\t ╚╩╩═╩╩═╩╩╩╩╝')
    
    print('\t╔╦╦═╦╗╔══╦═╦╦╗')
    print('\t║║║║║╚╬╗╔╣╩║╔╝')
    print('\t╚═╩═╩═╝╚╝╚╩╩╝')    
     
def painel_jogar (): #painel durante o jogo
    print('╔╦═╦═╦╦╗╔╦╦═╦╦╗╔╦═╦═╦═╦═╦═╦═╦╦╦═╦╗╔╦══╦═╦╗')
    print('║║║║║╚╣╚╝║║║║║╚╝║═╣ ║║║ ║░║║║║║║║╚╝║░░║║║║')
    print('║║╩║║╔╩╗╔╣║║║║╔╗║═╣ ║╩║ ║╔╣╩║╚╣╩╠╗╔╣╔╗╣╩║║')
    print('║╚╩╩═╝ ╚╝╚╩╩═╩╝╚╩═╝ ╚╩╝ ╚╝╚╩╩═╩╩╝╚╝╚╝╚╩╩╝║')
    print('╚════════════════════════════════════════╝')
    
    

entrar_jogo = input("Deseja abrir o jogo? ('s' ou 'n')\n ") #iniciar do jogo

if entrar_jogo != 's' and entrar_jogo != 'n': #mensagem de erro para controle
    while entrar_jogo != 's' and entrar_jogo != 'n':
        print('Resposta inválida. Digite novamente!')
        entrar_jogo = input("Deseja abrir o jogo? ('s' ou 'n')\n ")
        
if entrar_jogo == 's': #caso o usuário escolha iniciar o jogo 
    funcao = 'menu'
    
    if funcao == 'menu':
        while funcao == 'menu':
            menuiniciar1 ()
    
            funcao = input('O que deseja fazer?\n ')
    
            if funcao != 'jogar' and funcao != 'opcoes' and funcao != 'loja' and funcao != 'sair': #mensagem de erro para controle
                while funcao != 'jogar' and funcao != 'opcoes' and funcao != 'loja' and funcao != 'sair':
                    print('Resposta inválida. Digite novamente!')
                    funcao = input('O que deseja fazer?\n ')
                    
            if funcao == 'jogar':
                funcao = 'voltar'
                
                while funcao == 'voltar':
                    jogar1 ()
                    
                    funcao = input('O que deseja fazer?\n ')
                    
                    if funcao != 'facil' and funcao != 'medio' and funcao != 'dificil' and funcao != 'menu': #mensagem de erro para controle
                        while funcao != 'skins' and funcao != 'plano de fundo' and funcao != 'acessorios' and funcao != 'menu':
                            print('Resposta inválida. Digite novamente!')
                            funcao = input('O que deseja fazer?\n ')
                            
                    if funcao == 'facil':
                        painel_facil()
                    
                        funcao = input('O que deseja fazer?\n ')
                        if funcao != 'iniciar' and funcao != 'voltar': #mensagem de erro para controle
                            while funcao != 'iniciar' and funcao != 'voltar': 
                                print('Resposta inválida. Digite novamente!')
                                funcao = input('O que deseja fazer?\n ')
                                
                    if funcao == 'medio':
                        painel_medio()
                        
                        funcao = input('O que deseja fazer?\n ')
                        if funcao != 'iniciar' and funcao != 'voltar': #mensagem de erro para controle
                            while funcao != 'iniciar' and funcao != 'voltar':
                                print('Resposta inválida. Digite novamente!')
                                funcao = input('O que deseja fazer?\n ')
                                
                    if funcao == 'dificil':
                        painel_dificil()
                        
                        funcao = input('O que deseja fazer?\n ')
                        if funcao != 'iniciar' and funcao != 'voltar': #mensagem de erro para controle
                            while funcao != 'iniciar' and funcao != 'voltar':
                                print('Resposta inválida. Digite novamente!')
                                funcao = input('O que deseja fazer?\n ')
                                
            if funcao == 'sair':
                print('(ಥ﹏ಥ)')                    
                            
else: #caso o usuário não queira iniciar o jogo =(
    print('(ಥ﹏ಥ)')
# Out:
# Deseja abrir o jogo? ('s' ou 'n')
#  n
# (ಥ﹏ಥ)
