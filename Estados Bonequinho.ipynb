# %%
print('______')
print('|   _|_\n|  (   )')
print('|   ')
print('|  ')
print('|_')

print('______')
print('|   _|_\n|  (   )')
print('|    |')
print('|  ')
print('|_')

print('______')
print('|   _|_\n|  (   )')
print('|    |')
print('|   /')
print('|_')

print('______')
print('|   _|_\n|  (   )')
print('|    |')
print('|   /\\')
print('|_')

print('______')
print('|   _|_\n|  (   )')
print('|   <|')
print('|   /\\')
print('|_')

print('______')
print('|   _|_\n|  (   )')
print('|   <|>')
print('|   /\\')
print('|_')

print('______')
print('|   _|_\n|  (   )')
print('|   <|>')
print('|  _/\\')
print('|_')

print('______')
print('|   _|_\n|  (   )')
print('|   <|>')
print('|  _/\\_')
print('|_')

print('______')
print('|   _|_\n|  (._.)')
print('|   <|>')
print('|  _/\\_')
print('|_')

print('______')
print('|   _|_\n|  (x_x)')
print('|   <|>')
print('|  _/\\_')
print('|_')
# Out:
# ______
# |   _|_
# |  (   )
# |
# |
# |_
# ______
# |   _|_
# |  (   )
# |    |
# |
# |_
# ______
# |   _|_
# |  (   )
# |    |
# |   /
# |_
# ______
# |   _|_
# |  (   )
# |    |
# |   /\
# |_
# ______
# |   _|_
# |  (   )
# |   <|
# |   /\
# |_
# ______
# |   _|_
# |  (   )
# |   <|>
# |   /\
# |_
# ______
# |   _|_
# |  (   )
# |   <|>
# |  _/\
# |_
# ______
# |   _|_
# |  (   )
# |   <|>
# |  _/\_
# |_
# ______
# |   _|_
# |  (._.)
# |   <|>
# |  _/\_
# |_
# ______
# |   _|_
# |  (x_x)
# |   <|>
# |  _/\_
# |_
